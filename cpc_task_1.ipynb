# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshnitt/NITT_CPC_2021/blob/main/cpc_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
left=pd.read_csv(r"C:\Users\Adarsh Kumar\Downloads\Winter Week case study 1.xlsx - Employees who have left.csv")

# %%
left
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0      14999                0.37             0.52               2
# 1      14998                0.11             0.96               6
# 2      14997                0.37             0.53               2
# 3      14996                0.37             0.48               2
# 4      14995                0.40             0.57               2
# ...      ...                 ...              ...             ...
# 3566       5                0.10             0.89               2
# 3567       4                0.10             0.89               5
# 3568       3                0.10             0.89               7
# 3569       2                0.10             0.89               5
# 3570       1                0.10             0.89               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      158                   3              0
# ...

# %%
import  seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(left)

# %%
left
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0      14999                0.37             0.52               2
# 1      14998                0.11             0.96               6
# 2      14997                0.37             0.53               2
# 3      14996                0.37             0.48               2
# 4      14995                0.40             0.57               2
# ...      ...                 ...              ...             ...
# 3566       5                0.10             0.89               2
# 3567       4                0.10             0.89               5
# 3568       3                0.10             0.89               7
# 3569       2                0.10             0.89               5
# 3570       1                0.10             0.89               2
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 0                      158                   3              0
# ...

# %%
left.loc[:,["dept","salary","promotion_last_5years"]].groupby(["promotion_last_5years","salary"]).count().plot()
plt.title("No promotion and low salary guy leaving comapny fast",fontsize=20);

# %%
pd.crosstab(left["dept"],left["promotion_last_5years"]).plot()
import numpy as np
name=np.array(left.dept.unique())
plt.axvline(7,color="red")
plt.text(7,900,"sales")
# Out:
# Text(7, 900, 'sales')

# %%
satisfy=pd.crosstab(left["satisfaction_level"],left["dept"])
sns.heatmap(satisfy)
# Out:
# <AxesSubplot:xlabel='dept', ylabel='satisfaction_level'>

# %%
satisfy
# Out:
# dept                IT  RandD  accounting  hr  management  marketing  \
# satisfaction_level
# 0.09                17      5           7  12           3          6
# 0.10                45     17          30  28          20         37
# 0.11                31     11          25  18           9          6
# 0.12                 0      3           0   0           0          0
# 0.13                 0      0           0   0           0          0
# ...                 ..    ...         ...  ..         ...        ...
# 0.88                 1      1           4   0           1          1
# 0.89                 0      5           4   0           0          3
# 0.90                 6      0           4   0           1          3
# 0.91                 0      1           2   6           0          0
# 0.92                 2      1           0   0           0          0
#
# dept                product_mng  sales  support  technical
# satisfaction_level
# ...

# %%
happy=satisfy.mean(axis=0)/satisfy.mean(axis=0).sum()
happy.plot()
# Out:
# <AxesSubplot:xlabel='dept'>

# %%
satisfy.mean(axis=0)
# Out:
# dept
# IT              3.370370
# RandD           1.493827
# accounting      2.518519
# hr              2.654321
# management      1.123457
# marketing       2.506173
# product_mng     2.444444
# sales          12.518519
# support         6.851852
# technical       8.604938
# dtype: float64

# %%
filt=left.loc[:,["dept","salary"]].groupby(["dept"]).count()
filt.index
# Out:
# Index(['IT', 'RandD', 'accounting', 'hr', 'management', 'marketing',
#        'product_mng', 'sales', 'support', 'technical'],
#       dtype='object', name='dept')

# %%
left.loc[:,"time_spend_company"].groupby(left.loc[:,"dept"]).sum().plot()
plt.axvline(7,color="yellow")
plt.text(7,900,"sales")
plt.ylabel("time_sum")
plt.title("sales is more tough dept.. so people are leaving")
# Out:
# Text(0.5, 1.0, 'sales is more tough dept.. so people are leaving')

# %%
left.loc[:,"time_spend_company"].groupby(left.loc[:,"dept"]).sum()
# Out:
# dept
# IT             1054
# RandD           484
# accounting      774
# hr              807
# management      342
# marketing       783
# product_mng     790
# sales          3866
# support        2183
# technical      2760
# Name: time_spend_company, dtype: int64

# %%
left.loc[:,"last_evaluation"].groupby(left.loc[:,"satisfaction_level"]).sum().plot()
plt.ylabel("# of people")
plt.title("overall people is not liking work here");

# %%
fin=left.loc[:,["satisfaction_level","salary"]].groupby([left["dept"],left["salary"]]).sum()
fin1=fin/fin.sum()
fin1
# Out:
#                     satisfaction_level
# dept        salary
# IT          high              0.001544
#             low               0.049540
#             medium            0.021246
# RandD       high              0.000921
#             low               0.020775
#             medium            0.012998
# accounting  high              0.000828
#             low               0.031282
#             medium            0.020331
# hr          high              0.000994
#             low               0.035217
#             medium            0.022988
# management  high              0.000278
#             low               0.019901
#             medium            0.003955
# marketing   high              0.001683
#             low               0.044326
#             medium            0.012170
# product_mng high              0.001000
#             low               0.037046
#             medium            0.022173
# sales       high              0.001901
# ...

# %%
# sales dept people are not interested anymore.
